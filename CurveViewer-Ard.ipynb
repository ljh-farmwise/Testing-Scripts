# %%
# %matplotlib notebook

# import required modules
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import glob

# Select all CSV files on Desktop
files = glob.glob(r"\Users\Lawrence Hsiung\NEWtests1024\rr1\*.csv")
xaxis = np.linspace(0,1000, 10000)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

plt.title('NEW Characterizations ')
i = 0
startpos = []
endpos = []
for file in files:
    if 'open-' in file:
        s_time = time.time()
        df = pd.read_csv(file, header = None)
        e_time = time.time()
        #print("Read time: ", (e_time-s_time), "seconds")
        df= df.T
        #print(df)
        df.columns =['Ch1', 'Ch2', 'Ch3', 'Ch4']
        zpt = sum(df['Ch3'][200:400])/len(df['Ch3'][200:400])
        df['Ch3'] = (df['Ch3']-zpt)/0.066666 #calibration factor
        df['Ch4'] = df['Ch4'] - 0.13
        
        if len(df['Ch3']) < 10005:
            ax1.plot(xaxis[4500:8500], df['Ch1'][4500:8500], label = 'INPUT %s' %i)
            ax2.plot(xaxis[4500:8500], df['Ch3'][4500:8500], label = '%s' %file[-22:])
            startpos.append(sum(df['Ch3'][2500:3500])/len(df['Ch3'][2500:3500]))
            endpos.append(sum(df['Ch3'][7500:8500])/len(df['Ch3'][7500:8500]))
            i+=1

plt.axvline(x=505, ls = ':', c = 'g')
plt.axvline(x=555, ls = ':', c = 'g')
plt.axvline(x=528, ls = ':', c = 'r')
# plt.axvline(x=57, ls = ':', c = 'r')
# plt.axvline(x=61, ls = ':', c = 'g')
ax1.set_xlabel('10*ms')
ax1.set_ylabel('Vsense', color='g')
ax2.set_ylabel('angle delta', color='b')
ax1.set_ylim([-0.5, 5])

#plt.legend()
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()
print(i)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 140

# %%
for x in range(len(endpos)):
    print(endpos[x]-startpos[x])
# Out:
# 26.394534794682773
# 27.1877521773067
# 27.688434679018094
# 28.32583458170714
# 28.630998476574884
# 29.052830405125473
# 28.35802092345251
# 27.842234299973907
# 27.64221278614727
# 28.51566242862212
# 28.83953873495865
# 27.697649237016257
# 27.25826789946271
# 28.224519174591872
# 28.34098343433839
# 27.648753432493304
# 27.48536152624279
# 28.07291136597547
# 27.864112662599425
# 28.036266848111254

# %%
fig = plt.figure()
plt.title('Characterizations Open AVX')
i = 0
xaxis = np.linspace(0,1000, 10000)
files = glob.glob(r"\Users\Lawrence Hsiung\1010prestudy\*.csv")
for file in files:
    if 'open-0.019' in file:
        s_time = time.time()
        df = pd.read_csv(file, header = None)
        e_time = time.time()
        #print("Read time: ", (e_time-s_time), "seconds")
        df= df.T
        #print(df)
        df.columns =['Ch1', 'Ch2', 'Ch3', 'Ch4']
        zpt = sum(df['Ch3'][200:400])/len(df['Ch3'][200:400])
        df['Ch3'] = (df['Ch3']-zpt)*15 #calibration factor
        df['Ch1'] = df['Ch1'] - 0.126
        plt.plot(xaxis, df['Ch4'], label = 'INPUT %s' %i)

        plt.plot(xaxis[2000:9000], -df['Ch3'][2000:9000], label = '%s' %file[-22:])
        i+=1

plt.axvline(x=505, ls = ':', c = 'g')
plt.axvline(x=555, ls = ':', c = 'g')
plt.axvline(x= 528, ls = ':', c = 'r')
# plt.axvline(x=61, ls = ':', c = 'g')
plt.xlabel('ms')
plt.ylabel('angle delta')

#plt.legend()
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()
print(i)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 20

# %%
fig = plt.figure()

s_time = time.time()
df = pd.read_csv("\\Users\\Lawrence Hsiung\\NEWtests1024\\rr2\\NEW-Test1024-avx-open-1.0-9.csv" , header=None)
e_time = time.time()
#print("Read time: ", (e_time-s_time), "seconds")
df= df.T
#print(df)
df.columns =['Ch1', 'Ch2', 'Ch3', 'Ch4']
zpt = sum(df['Ch3'][200:400])/len(df['Ch3'][200:400])
df['Ch3'] = (df['Ch3']-zpt)/0.066666 #calibration factor
df['Ch1'] = df['Ch1'] - 0.126
plt.plot(xaxis, df['Ch4'], label = 'NEW')

plt.plot(xaxis[2000:9000], df['Ch3'][2000:9000], label = 'NEW')

s_time = time.time()
df = pd.read_csv("\\Users\\Lawrence Hsiung\\1005wpremph\\Test1005-open-1.0-10.csv" , header=None)
e_time = time.time()
#print("Read time: ", (e_time-s_time), "seconds")
df= df.T
#print(df)
df.columns =['Ch1', 'Ch2', 'Ch3', 'Ch4']
zpt = sum(df['Ch3'][200:400])/len(df['Ch3'][200:400])
df['Ch3'] = (df['Ch3']-zpt)*22.5#calibration factor
df['Ch1'] = df['Ch1'] - 0.126
plt.plot(xaxis, df['Ch4'], label = 'OLD')

plt.plot(xaxis[2000:9000], -df['Ch3'][2000:9000], label = 'OLD')

#plt.axvline(x=505, ls = '-', c = 'y')
plt.axvline(x=560, ls = ':', c = 'g')
plt.axvline(x= 527, ls = ':', c = 'r')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

# import required modules
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import glob

# Select all CSV files on Desktop
files = glob.glob(r"\Users\Lawrence Hsiung\NEWtests1024\rr1\*.csv")


xaxis = np.linspace(0,100, 100)
fig = plt.figure()
plt.title('NEW Characterizations coldstart ')


for file in files:
    if 'close-1.0' in file: 
        s_time = time.time()
        df = pd.read_csv(file, header = None)
        e_time = time.time()
        #print("Read time: ", (e_time-s_time), "seconds")
        df= df.T
        #print(df)
        df.columns =['Ch1', 'Ch2', 'Ch3', 'Ch4']
        zpt = sum(df['Ch3'][200:400])/len(df['Ch3'][200:400])
        df['Ch3'] = (df['Ch3']-zpt)/0.0666666 #calibration factor
        df['Ch2'] = df['Ch2'] - 0.126
        
        if len(df['Ch3']) < 10005:
            endpos = sum(df['Ch3'][8500:9500])/1000
            name = int(file[-6:-4])
            if name < 0:
                name = -name
            plt.scatter(name, endpos)
            
plt.xlabel('Run #')
plt.ylabel('End pos')

plt.show()
print("Done")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Done

# %%
# %matplotlib notebook

# import required modules
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import glob

# Select all CSV files on Desktop
files = glob.glob(r"\Users\Lawrence Hsiung\1010prestudy\*.csv")
xaxis = np.linspace(0,1000, 10000)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

plt.title('Characterizations preemphasis study PT 1.9A ')

for file in files:
    if '-13' in file:
        s_time = time.time()
        df = pd.read_csv(file, header = None)
        e_time = time.time()
        #print("Read time: ", (e_time-s_time), "seconds")
        df= df.T
        #print(df)
        df.columns =['Ch1', 'Ch2', 'Ch3', 'Ch4']
        zpt = sum(df['Ch3'][200:400])/len(df['Ch3'][200:400])
        df['Ch3'] = (df['Ch3']-zpt)*22.5 #calibration factor
        df['Ch4'] = df['Ch4'] - 0.13
        
        if len(df['Ch3']) < 10005:
            ax1.plot(xaxis, df['Ch4'], label = 'INPUT %s' %i)
            
            ax2.plot(xaxis[2000:9000], df['Ch3'][2000:9000], label = '%s' %file[-22:])
            i+=0.001

# plt.axvline(x=505, ls = ':', c = 'g')
# plt.axvline(x=555, ls = ':', c = 'g')
# plt.axvline(x=528, ls = ':', c = 'r')
# plt.axvline(x=57, ls = ':', c = 'r')
# plt.axvline(x=61, ls = ':', c = 'g')
ax1.set_xlabel('ms')
ax1.set_ylabel('Vsense', color='g')
ax2.set_ylabel('angle delta', color='b')

#plt.legend()
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()
print(i)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.030000000000000016
